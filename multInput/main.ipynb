# %%
from typing import List,TypedDict
from unittest import result

from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    values: List[int]
    name:str
    result:str

# %%
def precess_values(state : AgentState) -> AgentState:
    """this function handles multi different input"""
    state["result"] = f"Hi there {state['name']}, you sum {sum(state['values'])}"
    return state

# %%
graph = StateGraph(AgentState)
graph.add_node("processer", precess_values)
graph.set_entry_point("processer")
graph.set_finish_point("processer")
app = graph.compile()

# %%
from IPython.display import display, Image
display(Image(app.get_graph().draw_mermaid_png()))

# %%
result = app.invoke({"values":[1,2,3,4],"name":"zlpei"})

# %%
print(result)
# Out:
# {'values': [1, 2, 3, 4], 'name': 'zlpei', 'result': 'Hi there zlpei, you sum 10'}
